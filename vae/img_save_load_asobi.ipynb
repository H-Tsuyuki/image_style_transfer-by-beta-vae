# %%
import pickle, os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

with open("cifar-10-batches-py/data_batch_1", "rb") as fp:
    train = pickle.load(fp, encoding="latin-1")
with open("cifar-10-batches-py/data_batch_2", "rb") as fp:
    test = pickle.load(fp, encoding="latin-1")
    
def parse_pickle(rawdata, rootdir):
    for i in range(100):
        dir = rootdir + "/" + f"{i:02d}"
        if not os.path.exists(dir):
            os.mkdir(dir)    
    m = len(rawdata["filenames"])
    for i in range(m):
        if i % 100 == 0:
            print(i)
        filename = rawdata["filenames"][i]
        label = rawdata["labels"][i]
        data = rawdata["data"][i]
        data = data.reshape(3, 32, 32)
        data = np.swapaxes(data, 0, 2)
        data = np.swapaxes(data, 0, 1)
        #with Image.fromarray(data) as img:
        #    img.save(f"{rootdir}/{label:02d}/{filename}")

parse_pickle(train, "cifar10-raw/train")
parse_pickle(test, "cifar10-raw/test")
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms

import json
import numpy as np
from PIL import Image
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
)

preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize
])

img = Image.open('./cifar10-raw/test/00/fighter_s_000094.png')
print(img)
img_tensor = preprocess(img)
print(img_tensor.shape)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=32x32 at 0x7F7E80387940>
# torch.Size([3, 224, 224])

# %%
preprocess2 = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224)
])
print(img)
trans_img = preprocess(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=32x32 at 0x7F7E80387940>

# %%
print(img)
print(type(trans_img))  # <class 'PIL.Image.Image'>
trans_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=32x32 at 0x7F7E80387940>
# <class 'torch.Tensor'>
# tensor([[[ 1.3584,  1.3413,  1.3413,  ...,  1.4954,  1.4954,  1.4954],
#          [ 1.3584,  1.3413,  1.3413,  ...,  1.4783,  1.4783,  1.4783],
#          [ 1.3413,  1.3242,  1.3242,  ...,  1.4612,  1.4612,  1.4612],
#          ...,
#          [-0.3541, -0.3541, -0.3369,  ..., -1.2445, -1.1932, -1.1418],
#          [-0.3712, -0.3712, -0.3712,  ..., -1.2617, -1.2103, -1.1589],
#          [-0.3883, -0.3883, -0.3883,  ..., -1.2788, -1.2274, -1.1932]],
#
#         [[ 1.5007,  1.5007,  1.4832,  ...,  1.6408,  1.6408,  1.6408],
#          [ 1.4832,  1.4832,  1.4832,  ...,  1.6408,  1.6408,  1.6232],
#          [ 1.4832,  1.4832,  1.4832,  ...,  1.6232,  1.6232,  1.6232],
#          ...,
#          [ 0.0301,  0.0301,  0.0301,  ..., -1.0728, -1.0028, -0.9503],
#          [-0.0049, -0.0049, -0.0049,  ..., -1.0903, -1.0203, -0.9678],
# ...
